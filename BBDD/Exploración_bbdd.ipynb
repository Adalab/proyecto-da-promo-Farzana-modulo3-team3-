# %%
import pandas as pd
import random

# %%
rh = pd.read_csv('HR_RAW_DATA.csv', index_col=0)
pd.set_option('display.max_columns', None)
rh
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 0             162,0                        1       0         51
# 1             259,0                        3       0         65
# 2             319,0                        3       0         58
# 3               NaN                        1       1         82
# 4               NaN                        1       1         45
# ...             ...                      ...     ...        ...
# 1609          967,0                        3       0         51
# 1610          972,0                        3       0         57
# 1611            NaN                       13       0         41
# 1612          990,0                        1       0         84
# 1613            NaN                        4       0         75
#
#       JobInvolvement  JobLevel                   JobRole  JobSatisfaction  \
# 0                  3         5        resEArch DIREcToR                 3
# 1                  2         5                  ManAGeR                 3
# 2                  3         5                  ManaGER                 4
# 3                  3         4        ReseArCH DIrECtOr                 3
# 4                  4         4          sAleS EXECUtIve                 1
# ...              ...       ...                       ...              ...
# 1609               2         3          saLEs ExeCUTiVe                 4
# 1610               3         2    LAboRaTOry tECHNiCIAn                 2
# 1611               4         3          sAlES ExECUTivE                 3
# 1612               3         2          SaLes ExecUtIVe                 4
# 1613               3         3   mAnUfactURInG DiRECTOr                 3
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0              NaN       19537,0         6462                   7      Y
# 1              NaN       19999,0         5678                   0    NaN
# 2          Married       19232,0         4933                   1    NaN
# 3          Married       17169,0        26703                   3      Y
# 4         Divorced           NaN         7739                   2      Y
# ...            ...           ...          ...                 ...    ...
# 1609       Married       10325,0         5518                   1      Y
# 1610           NaN        4447,0        23163                   1    NaN
# 1611        Single           NaN         2560                   0    NaN
# 1612      Divorced           NaN        25952                   4    NaN
# 1613           NaN       10845,0        24208                   6      Y
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0          No                 13               3,0                         3
# 1         NaN                 14               3,0                         1
# 2          No                 11               3,0                         4
# 3         NaN                 19               3,0                         2
# 4          No                 12               3,0                         4
# ...       ...                ...               ...                       ...
# 1609      NaN                 11               NaN                         1
# 1610      NaN                 12               3,0                         2
# 1611       No                 18               3,0                         4
# 1612       No                 13               NaN                         4
# 1613      NaN                 13               3,0                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 0              NaN                 0               NaN                      5
# 1              NaN                 1              34,0                      5
# 2              NaN                 0              22,0                      3
# 3              NaN                 2               NaN                      2
# 4              NaN                 1               NaN                      5
# ...            ...               ...               ...                    ...
# 1609           NaN                 1               NaN                      6
# 1610           NaN                 0               NaN                      5
# 1611           NaN                 0               9,0                      3
# 1612           NaN                 2              12,0                      3
# 1613           NaN                 1               NaN                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 0                3,0              20                NaN
# 1                3,0              33                NaN
# 2                NaN              22                NaN
# 3                NaN              20                NaN
# 4                3,0              19                NaN
# ...              ...             ...                ...
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1611             3,0               8                NaN
# 1612             3,0               7                NaN
# 1613             3,0               8                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 0                          15                    15             19537,0
# 1                          11                     9             19999,0
# 2                          11                    15             19232,0
# 3                           5                     6             17169,0
# 4                           2                     8                 NaN
# ...                       ...                   ...                 ...
# 1609                        3                     7             10325,0
# 1610                        0                     8              4447,0
# 1611                        0                     7                 NaN
# 1612                        0                     7                 NaN
# 1613                        0                     7             10845,0
#
#       DateBirth       Salary                       RoleDepartament  \
# 0          1972  1000000000$                                   NaN
# 1          1971  1000000000$                                   NaN
# 2          1981  1000000000$   ManaGER  -  Research & Development
# 3          1976  1000000000$                                   NaN
# 4          1977  1000000000$                                   NaN
# ...         ...          ...                                   ...
# 1609       1987  1000000000$                                   NaN
# 1610       1978  1000000000$                                   NaN
# 1611       1984  1000000000$                                   NaN
# 1612       1987  1000000000$                                   NaN
# 1613       1977  1000000000$                                   NaN
#
#       NUMBERCHILDREN RemoteWork
# 0                NaN        Yes
# 1                NaN          1
# 2                NaN          1
# 3                NaN      False
# 4                NaN          0
# ...              ...        ...
# 1609             NaN          0
# 1610             NaN          1
# 1611             NaN        Yes
# 1612             NaN       True
# 1613             NaN          0
#
# [1614 rows x 41 columns]

# %%
rh.sample(10)
# Out:
#              Age Attrition     BusinessTravel DailyRate Department  \
# 72            49        No                NaN    465,0$        NaN
# 343           27        No  travel_frequently    294,0$        NaN
# 986           26       Yes         non-travel    265,0$        NaN
# 793           40        No                NaN   1194,0$        NaN
# 1195          34        No                NaN    216,0$        NaN
# 390           29        No      travel_rarely    718,0$        NaN
# 445           49        No                NaN    809,0$        NaN
# 532           37        No      travel_rarely    799,0$        NaN
# 426   thirty-one        No                NaN    326,0$        NaN
# 1467          39        No         non-travel    105,0$        NaN
#
#       DistanceFromHome  Education EducationField  employeecount  \
# 72                   6          1  Life Sciences              1
# 343                 10          2            NaN              1
# 986                 29          2        Medical              1
# 793                  2          4            NaN              1
# 1195               -46          4            NaN              1
# 390                  8          1        Medical              1
# 445                  1          3            NaN              1
# 532                -47          3            NaN              1
# 426                  8          2            NaN              1
# 1467                 9          3            NaN              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 72           1661,0                        3       1         41
# 343           733,0                        4       0         32
# 986          1037,0                        2       0         79
# 793             NaN                        3       1         98
# 1195            NaN                       46       0         75
# 390             NaN                        2       0         79
# 445             NaN                        3       0         36
# 532             NaN                       47       1         59
# 426             NaN                        1       0         31
# 1467            NaN                        4       0         87
#
#       JobInvolvement  JobLevel                      JobRole  JobSatisfaction  \
# 72                 2         4   healthcArE repReSEnTaTive                 3
# 343                3         3      MaNufACtURiNg DirEctOr                 1
# 986                1         2             SAleS ExeCutiVE                 1
# 793                3         1          reSearcH sCiENTist                 3
# 1195               4         2             SaLEs eXeCUtivE                 4
# 390                2         2      maNUfaCTUrinG DIReCtOR                 4
# 445                3         4                     MANAgEr                 3
# 532                3         3      MAnUfaCTUrINg dIrEctor                 4
# 426                3         3             Sales eXEcUTive                 4
# 1467               3         5                     MANaGeR                 4
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 72             NaN           NaN        11652                   2    NaN
# 343            NaN        8793,0         4809                   1      Y
# 986         Single        4969,0        21813                   8      Y
# 793        Married        2001,0        12549                   2      Y
# 1195      Divorced           NaN        12278                   0      Y
# 390        Married           NaN        17689                   1    NaN
# 445         Single           NaN        22384                   4      Y
# 532         Single           NaN        23848                   4      Y
# 426       Divorced       10793,0         8386                   1    NaN
# 1467           NaN       19431,0        15302                   2    NaN
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 72        NaN                 19               3,0                         2
# 343        No                 21               4,0                         3
# 986        No                 18               3,0                         4
# 793       NaN                 14               3,0                         2
# 1195       No                 11               3,0                         4
# 390       NaN                 15               3,0                         3
# 445       NaN                 14               3,0                         1
# 532       NaN                 17               3,0                         4
# 426       NaN                 18               NaN                         1
# 1467      NaN                 13               3,0                         3
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 72            80,0                 1               NaN                      3
# 343            NaN                 2               9,0                      4
# 986           80,0                 0               NaN                      6
# 793            NaN                 3              20,0                      2
# 1195           NaN                 1              16,0                      2
# 390           80,0                 1              10,0                      2
# 445           80,0                 0              23,0                      2
# 532            NaN                 0               NaN                      3
# 426            NaN                 1              13,0                      5
# 1467           NaN                 0               NaN                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 72               3,0              15                NaN
# 343              2,0               9                NaN
# 986              3,0               2                NaN
# 793              3,0               5                NaN
# 1195             2,0              15                NaN
# 390              2,0              10                NaN
# 445              3,0               8                NaN
# 532              4,0               6                NaN
# 426              3,0              13                NaN
# 1467             2,0               6                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 72                          2                    12                 NaN
# 343                         1                     7              8793,0
# 986                         2                     2              4969,0
# 793                         0                     2              2001,0
# 1195                        0                     9                 NaN
# 390                         1                     2                 NaN
# 445                         0                     0                 NaN
# 532                         1                     2                 NaN
# 426                         9                     9             10793,0
# 1467                        1                     3             19431,0
#
#       DateBirth       Salary RoleDepartament  NUMBERCHILDREN RemoteWork
# 72         1974  1000000000$             NaN             NaN        Yes
# 343        1996  1000000000$             NaN             NaN          1
# 986        1997  1000000000$             NaN             NaN        Yes
# 793        1983  1000000000$             NaN             NaN        Yes
# 1195       1989  1000000000$             NaN             NaN        Yes
# 390        1994  1000000000$             NaN             NaN        Yes
# 445        1974  1000000000$             NaN             NaN       True
# 532        1986  1000000000$             NaN             NaN        Yes
# 426        1992  1000000000$             NaN             NaN       True
# 1467       1984  1000000000$             NaN             NaN      False

# %%
rh.shape
# Out:
# (1614, 41)

# %%
rh.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'employeecount',
#  'employeenumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NUMCOMPANIESWORKED',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TOTALWORKINGYEARS',
#  'TrainingTimesLastYear',
#  'WORKLIFEBALANCE',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YEARSWITHCURRMANAGER',
#  'SameAsMonthlyIncome',
#  'DateBirth',
#  'Salary',
#  'RoleDepartament',
#  'NUMBERCHILDREN',
#  'RemoteWork']

# %%
rh.describe(include='all')
# Out:
#          Age Attrition BusinessTravel DailyRate                Department  \
# count   1614      1614            842      1614                       302
# unique    54         2              3       849                         3
# top       35        No  travel_rarely      nan$   Research & Development
# freq      84      1355            586       124                       196
# mean     NaN       NaN            NaN       NaN                       NaN
# std      NaN       NaN            NaN       NaN                       NaN
# min      NaN       NaN            NaN       NaN                       NaN
# 25%      NaN       NaN            NaN       NaN                       NaN
# 50%      NaN       NaN            NaN       NaN                       NaN
# 75%      NaN       NaN            NaN       NaN                       NaN
# max      NaN       NaN            NaN       NaN                       NaN
#
#         DistanceFromHome    Education EducationField  employeecount  \
# count        1614.000000  1614.000000            869         1614.0
# unique               NaN          NaN              6            NaN
# top                  NaN          NaN  Life Sciences            NaN
# freq                 NaN          NaN            349            NaN
# mean            4.527261     2.925031            NaN            1.0
# std            14.591913     1.022357            NaN            0.0
# min           -49.000000     1.000000            NaN            1.0
# 25%             2.000000     2.000000            NaN            1.0
# 50%             5.000000     3.000000            NaN            1.0
# 75%            11.000000     4.000000            NaN            1.0
# max            29.000000     5.000000            NaN            1.0
#
#        employeenumber  EnvironmentSatisfaction       Gender     HourlyRate  \
# count            1183              1614.000000  1614.000000           1614
# unique           1079                      NaN          NaN             72
# top             482,0                      NaN          NaN  Not Available
# freq                2                      NaN          NaN             84
# mean              NaN                 4.294919     0.398389            NaN
# std               NaN                 6.993559     0.489718            NaN
# min               NaN                 1.000000     0.000000            NaN
# 25%               NaN                 2.000000     0.000000            NaN
# 50%               NaN                 3.000000     0.000000            NaN
# 75%               NaN                 4.000000     1.000000            NaN
# max               NaN                49.000000     1.000000            NaN
#
#         JobInvolvement     JobLevel    JobRole  JobSatisfaction MaritalStatus  \
# count      1614.000000  1614.000000       1614      1614.000000           963
# unique             NaN          NaN       1579              NaN             5
# top                NaN          NaN   mANager               NaN       Married
# freq               NaN          NaN          4              NaN           404
# mean          2.739777     2.068154        NaN         2.738538           NaN
# std           0.711567     1.101344        NaN         1.106163           NaN
# min           1.000000     1.000000        NaN         1.000000           NaN
# 25%           2.000000     1.000000        NaN         2.000000           NaN
# 50%           3.000000     2.000000        NaN         3.000000           NaN
# 75%           3.000000     3.000000        NaN         4.000000           NaN
# max           4.000000     5.000000        NaN         4.000000           NaN
#
#        MonthlyIncome   MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  \
# count            771   1614.000000         1614.000000    713      938
# unique           668           NaN                 NaN      1        2
# top           6347,0           NaN                 NaN      Y       No
# freq               4           NaN                 NaN    713      682
# mean             NaN  14284.495663            2.673482    NaN      NaN
# std              NaN   7110.414585            2.506152    NaN      NaN
# min              NaN   2094.000000            0.000000    NaN      NaN
# 25%              NaN   8001.000000            1.000000    NaN      NaN
# 50%              NaN  14248.500000            2.000000    NaN      NaN
# 75%              NaN  20364.000000            4.000000    NaN      NaN
# max              NaN  26999.000000            9.000000    NaN      NaN
#
#         PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# count         1614.000000              1419               1614.000000
# unique                NaN                 2                       NaN
# top                   NaN               3,0                       NaN
# freq                  NaN              1205                       NaN
# mean            15.165428               NaN                  2.704461
# std              3.648610               NaN                  1.079031
# min             11.000000               NaN                  1.000000
# 25%             12.000000               NaN                  2.000000
# 50%             14.000000               NaN                  3.000000
# 75%             18.000000               NaN                  4.000000
# max             25.000000               NaN                  4.000000
#
#        StandardHours  StockOptionLevel TOTALWORKINGYEARS  \
# count            419       1614.000000              1088
# unique             1               NaN                40
# top             80,0               NaN              10,0
# freq             419               NaN               144
# mean             NaN          0.791202               NaN
# std              NaN          0.842396               NaN
# min              NaN          0.000000               NaN
# 25%              NaN          0.000000               NaN
# 50%              NaN          1.000000               NaN
# 75%              NaN          1.000000               NaN
# max              NaN          3.000000               NaN
#
#         TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# count             1614.000000            1506     1614.000000
# unique                    NaN               4             NaN
# top                       NaN             3,0             NaN
# freq                      NaN             913             NaN
# mean                 2.809789             NaN        7.132590
# std                  1.297765             NaN        6.124237
# min                  0.000000             NaN        0.000000
# 25%                  2.000000             NaN        3.000000
# 50%                  3.000000             NaN        5.000000
# 75%                  3.000000             NaN        9.000000
# max                  6.000000             NaN       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# count                  34              1614.000000           1614.000000
# unique                 10                      NaN                   NaN
# top                   2,0                      NaN                   NaN
# freq                   11                      NaN                   NaN
# mean                  NaN                 2.245973              4.220570
# std                   NaN                 3.235665              3.562695
# min                   NaN                 0.000000              0.000000
# 25%                   NaN                 0.000000              2.000000
# 50%                   NaN                 1.000000              3.000000
# 75%                   NaN                 3.000000              7.000000
# max                   NaN                15.000000             17.000000
#
#        SameAsMonthlyIncome    DateBirth       Salary      RoleDepartament  \
# count                  771  1614.000000         1614                  302
# unique                 668          NaN            1                  301
# top                 6347,0          NaN  1000000000$   MaNAgeR  -  Sales
# freq                     4          NaN         1614                    2
# mean                   NaN  1986.076208          NaN                  NaN
# std                    NaN     9.101332          NaN                  NaN
# min                    NaN  1963.000000          NaN                  NaN
# 25%                    NaN  1980.000000          NaN                  NaN
# 50%                    NaN  1987.000000          NaN                  NaN
# 75%                    NaN  1993.000000          NaN                  NaN
# max                    NaN  2005.000000          NaN                  NaN
#
#         NUMBERCHILDREN RemoteWork
# count              0.0       1614
# unique             NaN          5
# top                NaN          1
# freq               NaN        360
# mean               NaN        NaN
# std                NaN        NaN
# min                NaN        NaN
# 25%                NaN        NaN
# 50%                NaN        NaN
# 75%                NaN        NaN
# max                NaN        NaN

# %% [markdown]
# ABC Corporation
# Podemos dividir la BBDD en 3 partes: Datos personales de los empleados, Datos de relación con la empresa, Datos de satisfacción
# PK: Employee number
