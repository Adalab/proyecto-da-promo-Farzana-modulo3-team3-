# %%
import pandas as pd
import numpy as np
import re

# %%
bd  = pd.read_csv("datos_limpios_final.csv", index_col = 0)
pd.set_option("display.max.columns", None)
bd
# Out:
#       age attrition  distance_from_home  education  environment_satisfaction  \
# 0      51         N                 6.0          3                         1
# 1      52         N                 1.0          4                         3
# 2      42         N                 4.0          2                         3
# 3      47         N                 2.0          4                         1
# 4      46         N                 3.0          3                         1
# ...   ...       ...                 ...        ...                       ...
# 1609   36         Y                 3.0          1                         3
# 1610   45         N                 4.0          2                         3
# 1611   39         N                 NaN          5                         1
# 1612   36         N                 8.0          4                         1
# 1613   46         N                 7.0          2                         4
#
# ...

# %%
bd.columns.to_list()
# Out:
# ['age',
#  'attrition',
#  'distance_from_home',
#  'education',
#  'environment_satisfaction',
#  'gender',
#  'job_involvement',
#  'job_level',
#  'job_role',
#  'job_satisfaction',
#  'marital_status',
#  'monthly_rate',
#  'num_companies_worked',
#  'percent_salary_hike',
#  'performance_rating',
#  'relationship_satisfaction',
#  'stock_option_level',
#  'total_working_years',
#  'training_times_last_year',
#  'work_life_balance',
#  'years_at_company',
#  'years_since_last_promotion',
#  'years_with_curr_manager',
#  'remote_work',
#  'hourly_rate']
