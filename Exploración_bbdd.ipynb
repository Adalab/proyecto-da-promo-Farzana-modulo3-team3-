# %%
import pandas as pd
import random

# %%
rh = pd.read_csv('HR_RAW_DATA.csv', index_col=0)
pd.set_option('display.max_columns', None)
rh
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
rh.sample(10)
# Out:
#      Age Attrition     BusinessTravel DailyRate Department  DistanceFromHome  \
# 1283  42        No      travel_rarely    810,0$        NaN                23
# 445   49        No                NaN    809,0$        NaN                 1
# 995   33        No      travel_rarely    654,0$        NaN                 5
# 468   26        No  travel_frequently   1096,0$        NaN                 6
# 640   29        No                NaN    995,0$        NaN                 2
# 1138  35        No                NaN    219,0$        NaN               -16
# 1587  41        No                NaN    314,0$        NaN                 1
# 1410  34        No                NaN    479,0$        NaN               -13
# 107   29        No      travel_rarely   1389,0$        NaN                21
# 1335  32       Yes      travel_rarely    374,0$        NaN                25
#
#       Education EducationField  employeecount employeenumber  \
# ...

# %%
rh.shape
# Out:
# (1614, 41)

# %%
rh.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'employeecount',
#  'employeenumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NUMCOMPANIESWORKED',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TOTALWORKINGYEARS',
#  'TrainingTimesLastYear',
#  'WORKLIFEBALANCE',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YEARSWITHCURRMANAGER',
#  'SameAsMonthlyIncome',
#  'DateBirth',
#  'Salary',
#  'RoleDepartament',
#  'NUMBERCHILDREN',
#  'RemoteWork']

# %%
rh.describe(include='all')
# Out:
#          Age Attrition BusinessTravel DailyRate                Department  \
# count   1614      1614            842      1614                       302
# unique    54         2              3       849                         3
# top       35        No  travel_rarely      nan$   Research & Development
# freq      84      1355            586       124                       196
# mean     NaN       NaN            NaN       NaN                       NaN
# std      NaN       NaN            NaN       NaN                       NaN
# min      NaN       NaN            NaN       NaN                       NaN
# 25%      NaN       NaN            NaN       NaN                       NaN
# 50%      NaN       NaN            NaN       NaN                       NaN
# 75%      NaN       NaN            NaN       NaN                       NaN
# max      NaN       NaN            NaN       NaN                       NaN
#
#         DistanceFromHome    Education EducationField  employeecount  \
# ...

# %% [markdown]
# ABC Corporation
# Podemos dividir la BBDD en 3 partes: Datos personales de los empleados, Datos de relación con la empresa, Datos de satisfacción
# PK: Employee number

# %%
rh = pd.read_csv('datos_limpios.csv', index_col=0)
pd.set_option('display.max_columns', None)
# Out:
#      age attrition business_travel  daily_rate                department  \
# 0     51         N             NaN       684.0                       NaN
# 1     52         N             NaN       699.0                       NaN
# 2     42         N   Travel_Rarely       532.0   Research & Development
# 3     47         N   Travel_Rarely       359.0                       NaN
# 4     46         N             NaN      1319.0                       NaN
# ...   ..       ...             ...         ...                       ...
# 1609  36         Y   Travel_Rarely       530.0                       NaN
# 1610  45         N      Non-Travel       805.0                       NaN
# 1611  39         N   Travel_Rarely       903.0                       NaN
# 1612  36         N      Non-Travel      1229.0                       NaN
# 1613  46         N             NaN       566.0                       NaN
#
#       distance_from_home  education   education_field employee_number  \
# ...

# %%
rh.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_curr_manager', 'role_departament', 'remote_work'],
#       dtype='object')

# %%
rh['remote_work'].unique()
# Out:
# array(['Y', 'N'], dtype=object)
